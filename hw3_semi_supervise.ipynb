# %% [markdown]
# # **Homework 3 - Convolutional Neural Network(CNN, 卷積神經網路)**
#
# ## 目標
# - 學會如使用 CNN 做影像分類
# - 使用影像增強改進預測準確度
# - 學會如何使用 Unlabeled Data(未分類資料) 和 Semi-Supervised 的收益
#
# ## Baselines
# - Easy
#     - 利用範例程式碼建立一個 CNN 模型，並使用已標註的圖片
# - Medium
#     - 修改模型參數、使用不同模型或使用影像增強，再利用已標註的圖片改進準確率
#     - 你可以透過增加一些程式碼到範例程式碼中達到此目標
#
# - Strong
#     - 使用未標註的資料來改進準確率
#     - 這裡可以使用未標註的 testing data
#     - 提示: 使用 semi-supervised learning, self-supervised learning

# %% [markdown]
# ## **About Data**
#
#
# 資料是從 food-11 資料集收集來的
# - 資料有稍微調整過
# - 訓練資料集: 280 * 11 張已標註圖片 + 6786 張"未"標註圖片
# - 驗證資料集: 60 * 11 張已標註圖片
# - 測試資料集: 3347 張圖片
# - 請勿使用網路上找到的原始資料或是標註 - **屬於作弊行為**
#
# 這分資料是 Food-11 ，顧名思義為這份資料有 11 種分類的食物，建議半夜的時候只做訓練就好，不要打開圖片，否則肚子餓了老師不負責。

# %%
# 抽卡!!!
# !/opt/bin/nvidia-smi
# Out:
# Tue Jan  4 01:52:50 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8    27W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Download the dataset
# You may choose where to download the data.

# Google Drive
# X !gdown --id '1f1EsN6aYHIdJ-wuenzB4tHC0GWPW_aZU' --output food-11.zip
# !gdown --id '17IuAieAAesOOmgqnVDyzxfJ_p8FhkQzh' --output food-11.zip 
# !gdown --id '1znOld3Bo-qrNN_krPjMsTdLG18fCLW4r' --output food-11.zip

# MEGA
# !sudo apt install megatools
# !megadl "https://mega.nz/#!zt1TTIhK!ZuMbg5ZjGWzWX1I6nEUbfjMZgCmAgeqJlwDkqdIryfg"

# Unzip the dataset.
# This may take some time.
# !unzip -q food-11.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1znOld3Bo-qrNN_krPjMsTdLG18fCLW4r
# To: /content/food-11.zip
# 100% 963M/963M [00:07<00:00, 136MB/s]

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Import Packages**
#
# First, we need to import packages that will be used later.
#
# In this homework, we highly rely on **torchvision**, a library of PyTorch.

# %%
# Import necessary packages.
import numpy as np
import torch
import torch.nn as nn
import torchvision.transforms as transforms
from PIL import Image
# "ConcatDataset" and "Subset" are possibly useful when doing semi-supervised learning.
from torch.utils.data import ConcatDataset, DataLoader, Subset
from torchvision.datasets import DatasetFolder

# This is for the progress bar.
from tqdm.auto import tqdm

# %% [markdown]
# ## **Dataset, Data Loader, and Transforms**
#
# Torchvision 提供許多好用的圖片前處理工具，如圖像包裝與增強
#
# 在這裡，因為我們資料已經根據分類放好了，所以我們不需額外對資料進行分類包裝，直接使用 **torchvision.datasets.DatasetFolder** 就好
#
# 請參考 [PyTorch official website](https://pytorch.org/vision/stable/transforms.html) 裡面有更多的資料變形、轉換的細節

# %%
from torchvision.transforms.transforms import RandomCrop
# It is important to do data augmentation in training.
# However, not every augmentation is useful.
# Please think about what kind of augmentation is helpful for food recognition.
train_tfm = transforms.Compose([
    # Resize the image into a fixed shape (height = width = 128)
    transforms.Resize((128, 128)),
    # You may add some transforms here.
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomAffine(30, translate=(0.3, 0.3), scale=(0.8, 1.2), shear=0.3),
    transforms.ColorJitter(brightness=(0.5, 1.5), contrast=(0.5, 1.5), saturation=(0.5, 1.5)),
    transforms.RandomRotation(30),
    # ToTensor() should be the last one of the transforms.
    transforms.ToTensor(),
])

# We don't need augmentations in testing and validation.
# All we need here is to resize the PIL image and transform it into Tensor.
test_tfm = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
])

# %%
# Batch size for training, validation, and testing.
# A greater batch size usually gives a more stable gradient.
# But the GPU memory is limited, so please adjust it carefully.
batch_size = 128

# Construct datasets.
# The argument "loader" tells how torchvision reads the data.
train_set = DatasetFolder("food-11/training/labeled", loader=lambda x: Image.open(x), extensions="jpg", transform=train_tfm)
valid_set = DatasetFolder("food-11/validation", loader=lambda x: Image.open(x), extensions="jpg", transform=test_tfm)
unlabeled_set = DatasetFolder("food-11/training/unlabeled", loader=lambda x: Image.open(x), extensions="jpg", transform=train_tfm)
test_set = DatasetFolder("food-11/testing", loader=lambda x: Image.open(x), extensions="jpg", transform=test_tfm)

# Construct data loaders.
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=True)
valid_loader = DataLoader(valid_set, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=True)
test_loader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## **Model**
#
# 範例模型只包含一些卷積層和一些全連接層(MLP)
#
#
# 因為輸入的圖片為彩色圖片，所以 channels 必須為 3
# 在每個卷積層中，通常輸入的通道會增長，而高度和寬度會縮小（或保持不變）。
#
#
# 在進入全連接層之前，特徵圖必須展平為單個一維向量（對於每個圖像）。
# 這些特徵然後由全連接層轉換，最後，我們獲得每個類的“logits”。
#
# ### **WARNING -- 你必須注意！**
# 您可以在此處自由修改模型架構以進一步改進。
# 但是，如果您想使用一些眾所周知的架構，例如 ResNet50，請確保 **沒有** 加載預訓練的權重。
# 使用此類預訓練模型被視為作弊，因此您將受到懲罰。
# 同樣，如果您使用 **torch.hub** 加載任何模塊，則您有責任確保沒有使用預訓練的權重。
#
# 例如：你要使用 ResNet-18 當作你的模型
#
# model = torchvision.models.resnet18(pretrained=**False**) → 合法
#
# model = torchvision.models.resnet18(pretrained=**True**)  → 這是**不**合法的

# %%
# class Classifier(nn.Module):
#     def __init__(self):
#         super(Classifier, self).__init__()
#         # The arguments for commonly used modules:
#         # torch.nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding)
#         # torch.nn.MaxPool2d(kernel_size, stride, padding)

#         # input image size: [3, 128, 128]
#         self.cnn_layers = nn.Sequential(
#             nn.Conv2d(3, 64, 3, 1, 1),
#             nn.BatchNorm2d(64),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),

#             nn.Conv2d(64, 128, 3, 1, 1),
#             nn.BatchNorm2d(128),
#             nn.ReLU(),
#             nn.MaxPool2d(2, 2, 0),

#             nn.Conv2d(128, 256, 3, 1, 1),
#             nn.BatchNorm2d(256),
#             nn.ReLU(),
#             nn.MaxPool2d(4, 4, 0),
#         )
#         self.fc_layers = nn.Sequential(
#             nn.Linear(256 * 8 * 8, 256),
#             nn.ReLU(),
#             nn.Linear(256, 256),
#             nn.ReLU(),
#             nn.Linear(256, 11)
#         )

#     def forward(self, x):
#         # input (x): [batch_size, 3, 128, 128]
#         # output: [batch_size, 11]

#         # Extract features by convolutional layers.
#         x = self.cnn_layers(x)

#         # The extracted feature map must be flatten before going to fully-connected layers.
#         x = x.flatten(1)

#         # The features are transformed by fully-connected layers to obtain the final logits.
#         x = self.fc_layers(x)
#         return x

# %% [markdown]
# ## **訓練**
# 只需運行提供的代碼，無需任何修改，即可完成監督學習。
#
# 函數“get_pseudo_labels”用於半監督學習。
# 如果您使用未標記的數據進行半監督學習，預計會獲得更好的準確率。
# 但是，您必須自己實現該功能，並且需要手動調整多個 hyperparameters。
#
# 再次請注意，**禁止**使用外部數據（或預訓練模型）進行訓練。

# %%
import torchvision
import os
import pickle
import shutil

# %%
def get_pseudo_labels(dataset, model, threshold=0.87):
  pseudo_label_folder = "./pseudo_label/"

  if(os.path.isdir(pseudo_label_folder)): 
    shutil.rmtree(pseudo_label_folder)
  os.mkdir(pseudo_label_folder)

  # This functions generates pseudo-labels of a dataset using given model.
  # It returns an instance of DatasetFolder containing images whose prediction confidences exceed a given threshold.
  # You are NOT allowed to use any models trained on external data for pseudo-labeling.
  device = "cuda" if torch.cuda.is_available() else "cpu"

  # Construct a data loader.
  data_loader = DataLoader(dataset, batch_size=batch_size, shuffle=False)

  # Make sure the model is in eval mode.
  model.eval()
  # Define softmax function.
  softmax = nn.Softmax(dim=-1)

  # Iterate over the dataset by batches.
  with tqdm(total=len(data_loader)) as pbar:
    ct = 0
    for batch in data_loader:
      img, _ = batch

      # Forward the data
      # Using torch.no_grad() accelerates the forward process.
      with torch.no_grad():
        logits = model(img.to(device))

      # Obtain the probability distributions by applying softmax on logits.
      probs = softmax(logits)

      # ---------- TODO ----------
      # Filter the data and construct a new dataset.
      for i in range(probs.shape[0]):
        if(torch.max(probs[i]) >= threshold):
          pseudo_label = probs[i].argmax(dim=-1)
          im = transforms.ToPILImage()(img[i])
          if(os.path.isdir(pseudo_label_folder+f"{pseudo_label.item():02d}/") == False):
            os.mkdir(pseudo_label_folder+f"{pseudo_label.item():02d}/")
          im.save(pseudo_label_folder+f"{pseudo_label.item():02d}/{ct}_{i}.jpg")
      
      pbar.update(1)
      ct += 1

  # FileNotFoundError
  try:
    dataset = DatasetFolder(pseudo_label_folder, loader=lambda x: Image.open(x), extensions="jpg", transform=train_tfm)
  except FileNotFoundError:
    dataset = None

  # # Turn off the eval mode.
  model.train()
  return dataset

# %% [markdown]
# ## _test

# %%
shutil.rmtree("./pseudo_label")

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

model = torchvision.models.efficientnet_b4(pretrained=False).to(device)
model.classifier = nn.Sequential(
    nn.Dropout(p=0.4),
    nn.Linear(in_features=1792, out_features=1000),
    nn.Dropout(p=0.4),
    nn.Linear(in_features=1000, out_features=11)
  ).to(device)
# model.add_module("mylayer", nn.Sequential(
#     nn.Dropout(p=0.4),
#     nn.Linear(in_features=model.classifier[-1].out_features, out_features=11)
#   ))
model.device = device

# %%
model
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): ConvNormActivation(
#       (0): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#             (1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): ConvNormActivation(
#             (0): Conv2d(48, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=24, bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(24, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 24, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): ConvNormActivation(
#             (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.00625, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.018750000000000003, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.03125, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(192, 192, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=192, bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(192, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 192, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(192, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043750000000000004, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(336, 56, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(56, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05625, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(56, 336, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(336, 336, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=336, bias=False)
#             (1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(336, 14, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(14, 336, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(336, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06875, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08125, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.09375, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(672, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10625000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.11875000000000001, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(960, 960, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=960, bias=False)
#             (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(960, 40, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(40, 960, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(960, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.14375000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15625, mode=row)
#       )
#       (4): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (5): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.16875, mode=row)
#       )
#       (6): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#       (7): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 272, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(272, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.18125000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(272, 1632, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(1632, 1632, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1632, bias=False)
#             (1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1632, 68, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(68, 1632, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(1632, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): ConvNormActivation(
#             (0): Conv2d(448, 2688, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(2688, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): ConvNormActivation(
#             (0): Conv2d(2688, 2688, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2688, bias=False)
#             (1): BatchNorm2d(2688, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(2688, 112, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(112, 2688, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): ConvNormActivation(
#             (0): Conv2d(2688, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(448, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.19375, mode=row)
#       )
#     )
#     (8): ConvNormActivation(
#       (0): Conv2d(448, 1792, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1792, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.4, inplace=False)
#     (1): Linear(in_features=1792, out_features=1000, bias=True)
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=1000, out_features=11, bias=True)
#   )
# )

# %%
pseudo_set = get_pseudo_labels(unlabeled_set, model)
len(pseudo_set)
# Out:
#   0%|          | 0/54 [00:00<?, ?it/s]
# torch.Size([128, 11]) torch.Size([128, 11])
# torch.Size([128, 11]) torch.Size([128, 11])
# torch.Size([128, 11]) torch.Size([128, 11])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-122-12e3371c0e8f> in <module>()
# ----> 1 pseudo_set = get_pseudo_labels(unlabeled_set, model)
#       2 len(pseudo_set)
#
# <ipython-input-115-747402389f95> in get_pseudo_labels(dataset, model, threshold)
#      28       # Using torch.no_grad() accelerates the forward process.
#      29       with torch.no_grad():
# ---> 30         logits = model(img.to(device))
#      31
#      32       # Obtain the probability distributions by applying softmax on logits.
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/efficientnet.py in forward(self, x)
#     210
#     211     def forward(self, x: Tensor) -> Tensor:
# --> 212         return self._forward_impl(x)
#     213
#     214
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/efficientnet.py in _forward_impl(self, x)
#     200
#     201     def _forward_impl(self, x: Tensor) -> Tensor:
# --> 202         x = self.features(x)
#     203
#     204         x = self.avgpool(x)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/efficientnet.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         result = self.block(input)
#     104         if self.use_res_connect:
#     105             result = self.stochastic_depth(result)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torchvision/ops/misc.py in forward(self, input)
#     149
#     150     def forward(self, input: Tensor) -> Tensor:
# --> 151         scale = self._scale(input)
#     152         return scale * input
#
# /usr/local/lib/python3.7/dist-packages/torchvision/ops/misc.py in _scale(self, input)
#     145         scale = self.fc1(scale)
#     146         scale = self.activation(scale)
# --> 147         scale = self.fc2(scale)
#     148         return self.scale_activation(scale)
#     149
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     441                             _pair(0), self.dilation, self.groups)
#     442         return F.conv2d(input, weight, bias, self.stride,
# --> 443                         self.padding, self.dilation, self.groups)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
#
# KeyboardInterrupt:

# %% [markdown]
# ## _

# %%
class History():
  def __init__(self):
    self.done_epoch = -1 # len(list) - 1
    self.metrics = {"train_loss":[], "train_acc":[], "valid_loss":[], "valid_acc":[], "semi_count":[]}
  def store_record(self, train_loss, train_acc, valid_loss, valid_acc, semi_count):
    self.metrics["train_loss"].append(train_loss)
    self.metrics["train_acc"].append(train_acc)
    self.metrics["valid_loss"].append(valid_loss)
    self.metrics["valid_acc"].append(valid_acc)
    self.metrics["semi_count"].append(semi_count)
    self.done_epoch += 1
  def load(self, path):
    if(os.path.isfile(path)):
      with open(path, 'rb') as f:
        self.metrics = pickle.load(f)
      self.done_epoch = len(self.metrics["train_loss"]) - 1
      return 1
    else:
      return -1
  def store(self, path):
    with open(path, 'wb') as f:
      pickle.dump(self.metrics, f)

# %%
store_path = "/content/drive/Shareddrives/未命名的共用雲端硬碟/AICourse_hw/hw3_semi_full/"
# store_path = "./temp/"
if(store_path[-1] != "/"):
  store_path += "/"
if(os.path.isdir(store_path) == False):
  os.mkdir(store_path)
# "cuda" only when GPUs are available.
device = "cuda" if torch.cuda.is_available() else "cpu"

# # Initialize a model, and put it on the device specified.
# model = Classifier().to(device)
# MY MODIFY
model = torchvision.models.efficientnet_b4(pretrained=False).to(device)
model.classifier = nn.Sequential(
    nn.Dropout(p=0.4, inplace=True),
    nn.Linear(in_features=1792, out_features=1000),
    nn.Dropout(p=0.4, inplace=True),
    nn.Linear(in_features=1000, out_features=11)
  ).to(device)
model.device = device

# For the classification task, we use cross-entropy as the measurement of performance.
criterion = nn.CrossEntropyLoss()

# Initialize optimizer, you may fine-tune some hyperparameters such as learning rate on your own.
optimizer = torch.optim.Adam(model.parameters(), lr=0.0003, weight_decay=1e-5)

# The number of training epochs.
n_epochs = 300 # 80

# Whether to do semi-supervised learning.
do_semi = True # False

history = History()
load_fg = -1
if(os.path.isfile(store_path+"history.pkl")):
  load_fg = history.load(store_path+"history.pkl")
  checkpoint = torch.load(store_path+f"model_{history.done_epoch}.pt")
  model.load_state_dict(checkpoint['model_state_dict'])
  optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
  
if(load_fg == 1):
  print(f"Load success! Training after {history.done_epoch+1}")

for epoch in range(n_epochs):
  if(load_fg==1 and epoch <= history.done_epoch):
    semi_count = history.metrics['semi_count'][epoch]
    if(semi_count == 0):
      print(f"Epoch {epoch} has no data doing semi-supervise")
    else:
      print(f"Epoch {epoch} has {semi_count} data to do semi-supervise")
    # with tqdm(total=len(train_loader)) as pbar:
    #   pbar.set_postfix({
    #     "Train": f"{epoch + 1:03d}/{n_epochs:03d}",
    #     "loss": f"{history.metrics['train_loss'][epoch]:.5f}",
    #     "acc": f"{history.metrics['train_acc'][epoch]:.5f}"
    #   })
    #   pbar.update(len(train_loader))
    print(f"Train: {epoch + 1:03d}/{n_epochs:03d}, loss={history.metrics['train_loss'][epoch]:.5f} acc={history.metrics['train_acc'][epoch]:.5f}")
    # with tqdm(total=len(valid_loader)) as pbar:
    #   pbar.set_postfix({
    #     "Valid": f"{epoch + 1:03d}/{n_epochs:03d}",
    #     "loss": f"{history.metrics['valid_loss'][epoch]:.5f}",
    #     "acc": f"{history.metrics['valid_acc'][epoch]:.5f}"
    #   })
    #   pbar.update(len(valid_loader))
    print(f"Valid: {epoch + 1:03d}/{n_epochs:03d}, loss={history.metrics['valid_loss'][epoch]:.5f} acc={history.metrics['valid_acc'][epoch]:.5f}")
    print()
    continue
  # ---------- TODO ----------
  # In each epoch, relabel the unlabeled dataset for semi-supervised learning.
  # Then you can combine the labeled dataset and pseudo-labeled dataset for the training.
  semi_count = 0
  if do_semi:
    # Obtain pseudo-labels for unlabeled data using trained model.
    pseudo_set = get_pseudo_labels(unlabeled_set, model)
    if(pseudo_set != None):
      # Construct a new dataset and a data loader for training.
      # This is used in semi-supervised learning only.
      concat_dataset = ConcatDataset([train_set, pseudo_set])
      train_loader = DataLoader(concat_dataset, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=True)
      semi_count = len(pseudo_set)
      print(f"Epoch {epoch} has {semi_count} data to do semi-supervise")
    else:
      train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=1, pin_memory=True)
      print(f"Epoch {epoch} has no data doing semi-supervise")

  # ---------- Training ----------
  # Make sure the model is in train mode before training.
  model.train()

  # These are used to record information in training.
  train_loss = []
  train_accs = []

  # Iterate the training set by batches.
  with tqdm(total=len(train_loader)) as pbar:
    for batch in train_loader:
      # A batch consists of image data and corresponding labels.
      imgs, labels = batch

      # Forward the data. (Make sure data and model are on the same device.)
      logits = model(imgs.to(device))

      # Calculate the cross-entropy loss.
      # We don't need to apply softmax before computing cross-entropy as it is done automatically.
      loss = criterion(logits, labels.to(device))

      # Gradients stored in the parameters in the previous step should be cleared out first.
      optimizer.zero_grad()

      # Compute the gradients for parameters.
      loss.backward()

      # Clip the gradient norms for stable training.
      grad_norm = nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)

      # Update the parameters with computed gradients.
      optimizer.step()

      # Compute the accuracy for current batch.
      acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

      # Record the loss and accuracy.
      train_loss.append(loss.item())
      train_accs.append(acc)

      pbar.update(1)

    # The average loss and accuracy of the training set is the average of the recorded values.
    train_loss = sum(train_loss) / len(train_loss)
    train_acc = sum(train_accs) / len(train_accs)

    # Print the information.
    # print(f"[ Train | {epoch + 1:03d}/{n_epochs:03d} ] loss = {train_loss:.5f}, acc = {train_acc:.5f}")
    pbar.set_postfix({
      "Train": f"{epoch + 1:03d}/{n_epochs:03d}",
      "loss": f"{train_loss:.5f}",
      "acc": f"{train_acc:.5f}"
    })

  # ---------- Validation ----------
  # Make sure the model is in eval mode so that some modules like dropout are disabled and work normally.
  model.eval()

  # These are used to record information in validation.
  valid_loss = []
  valid_accs = []

  # Iterate the validation set by batches.
  with tqdm(total=len(valid_loader)) as pbar:
    for batch in valid_loader:
      # A batch consists of image data and corresponding labels.
      imgs, labels = batch

      # We don't need gradient in validation.
      # Using torch.no_grad() accelerates the forward process.
      with torch.no_grad():
        logits = model(imgs.to(device))

      # We can still compute the loss (but not the gradient).
      loss = criterion(logits, labels.to(device))

      # Compute the accuracy for current batch.
      acc = (logits.argmax(dim=-1) == labels.to(device)).float().mean()

      # Record the loss and accuracy.
      valid_loss.append(loss.item())
      valid_accs.append(acc)

      pbar.update(1)

    # The average loss and accuracy for entire validation set is the average of the recorded values.
    valid_loss = sum(valid_loss) / len(valid_loss)
    valid_acc = sum(valid_accs) / len(valid_accs)

    # Print the information.
    # print(f"[ Valid | {epoch + 1:03d}/{n_epochs:03d} ] loss = {valid_loss:.5f}, acc = {valid_acc:.5f}")
    pbar.set_postfix({
      "Valid": f"{epoch + 1:03d}/{n_epochs:03d}",
      "loss": f"{valid_loss:.5f}",
      "acc": f"{valid_acc:.5f}"
    })
  print()

  # save model and history
  history.store_record(train_loss=train_loss, train_acc=train_acc, valid_loss=valid_loss, valid_acc=valid_acc, semi_count=semi_count)
  torch.save({'epoch': epoch, 'model_state_dict': model.state_dict(), 'optimizer_state_dict': optimizer.state_dict()}, store_path+f"model_{epoch}.pt")
  history.store(store_path+"history.pkl")

  if(epoch % 5 == 4):
    for i in range(1, 5):
      os.remove(store_path+f"model_{epoch-i}.pt")
# Out:
# Load success! Training after 258
# Epoch 0 has no data doing semi-supervise
# Train: 001/300, loss=2.49429 acc=0.07594
# Valid: 001/300, loss=2.39836 acc=0.09922
#
# Epoch 1 has no data doing semi-supervise
# Train: 002/300, loss=2.48689 acc=0.09531
# Valid: 002/300, loss=2.40109 acc=0.08516
#
# Epoch 2 has no data doing semi-supervise
# Train: 003/300, loss=2.50691 acc=0.08281
# Valid: 003/300, loss=2.40526 acc=0.09219
#
# Epoch 3 has no data doing semi-supervise
# Train: 004/300, loss=2.45840 acc=0.09469
# Valid: 004/300, loss=2.40200 acc=0.09922
#
# Epoch 4 has 42 data to do semi-supervise
# Train: 005/300, loss=2.45166 acc=0.09351
# Valid: 005/300, loss=2.38665 acc=0.09557
#
# Epoch 5 has 41 data to do semi-supervise
# Train: 006/300, loss=2.43996 acc=0.09327
# Valid: 006/300, loss=2.36887 acc=0.11510
#
# Epoch 6 has 14 data to do semi-supervise
# Train: 007/300, loss=2.41063 acc=0.11901
# Valid: 007/300, loss=3.44010 acc=0.15885
#
# Epoch 7 has 39 data to do semi-supervise
# Train: 008/300, loss=2.37219 acc=0.13332
# Valid: 008/300, loss=2.65844 acc=0.17057
#
# Epoch 8 has 77 data to do semi-supervise
# Train: 009/300, loss=2.33184 acc=0.15206
# Valid: 009/300, loss=2.31005 acc=0.18880
#
# Epoch 9 has 19 data to do semi-supervise
# Train: 010/300, loss=2.32456 acc=0.14936
# Valid: 010/300, loss=2.27918 acc=0.18125
#
# Epoch 10 has 26 data to do semi-supervise
# Train: 011/300, loss=2.29900 acc=0.17059
# Valid: 011/300, loss=2.85983 acc=0.16693
#
# Epoch 11 has 52 data to do semi-supervise
# Train: 012/300, loss=2.27654 acc=0.17148
# Valid: 012/300, loss=2.40118 acc=0.16250
#
# Epoch 12 has 2 data to do semi-supervise
# Train: 013/300, loss=2.27575 acc=0.17206
# Valid: 013/300, loss=2.14929 acc=0.19375
#
# Epoch 13 has 48 data to do semi-supervise
# Train: 014/300, loss=2.25741 acc=0.17915
# Valid: 014/300, loss=2.19546 acc=0.19297
#
# Epoch 14 has 3 data to do semi-supervise
# Train: 015/300, loss=2.24761 acc=0.18344
# Valid: 015/300, loss=2.16452 acc=0.22135
#
# Epoch 15 has 35 data to do semi-supervise
# Train: 016/300, loss=2.22641 acc=0.19149
# Valid: 016/300, loss=2.13586 acc=0.20599
#
# Epoch 16 has 9 data to do semi-supervise
# Train: 017/300, loss=2.20307 acc=0.19956
# Valid: 017/300, loss=2.10911 acc=0.23750
#
# Epoch 17 has 134 data to do semi-supervise
# Train: 018/300, loss=2.23096 acc=0.20531
# Valid: 018/300, loss=2.63778 acc=0.22786
#
# Epoch 18 has 54 data to do semi-supervise
# Train: 019/300, loss=2.20624 acc=0.21270
# Valid: 019/300, loss=2.23959 acc=0.22995
#
# Epoch 19 has 10 data to do semi-supervise
# Train: 020/300, loss=2.18817 acc=0.22670
# Valid: 020/300, loss=2.09469 acc=0.27188
#
# Epoch 20 has 28 data to do semi-supervise
# Train: 021/300, loss=2.16167 acc=0.23313
# Valid: 021/300, loss=2.07314 acc=0.24635
#
# Epoch 21 has 25 data to do semi-supervise
# Train: 022/300, loss=2.16041 acc=0.22817
# Valid: 022/300, loss=2.08630 acc=0.24375
#
# Epoch 22 has no data doing semi-supervise
# Train: 023/300, loss=2.12382 acc=0.23750
# Valid: 023/300, loss=2.06573 acc=0.29349
#
# Epoch 23 has 93 data to do semi-supervise
# Train: 024/300, loss=2.08415 acc=0.25722
# Valid: 024/300, loss=1.97954 acc=0.30885
#
# Epoch 24 has 11 data to do semi-supervise
# Train: 025/300, loss=2.08960 acc=0.26584
# Valid: 025/300, loss=1.99326 acc=0.24349
#
# Epoch 25 has 61 data to do semi-supervise
# Train: 026/300, loss=2.09936 acc=0.24370
# Valid: 026/300, loss=2.12344 acc=0.29453
#
# Epoch 26 has 22 data to do semi-supervise
# Train: 027/300, loss=2.05538 acc=0.27171
# Valid: 027/300, loss=1.93097 acc=0.28854
#
# Epoch 27 has 3 data to do semi-supervise
# Train: 028/300, loss=2.02633 acc=0.27060
# Valid: 028/300, loss=1.98839 acc=0.32891
#
# Epoch 28 has 99 data to do semi-supervise
# Train: 029/300, loss=2.03774 acc=0.26734
# Valid: 029/300, loss=1.93468 acc=0.29297
#
# Epoch 29 has 40 data to do semi-supervise
# Train: 030/300, loss=2.01143 acc=0.28667
# Valid: 030/300, loss=1.95280 acc=0.26328
#
# Epoch 30 has 4 data to do semi-supervise
# Train: 031/300, loss=1.98943 acc=0.29708
# Valid: 031/300, loss=2.27798 acc=0.29219
#
# Epoch 31 has 220 data to do semi-supervise
# Train: 032/300, loss=2.01969 acc=0.27043
# Valid: 032/300, loss=1.97251 acc=0.30104
#
# Epoch 32 has 25 data to do semi-supervise
# Train: 033/300, loss=1.97518 acc=0.29365
# Valid: 033/300, loss=1.83259 acc=0.32500
#
# Epoch 33 has 71 data to do semi-supervise
# Train: 034/300, loss=1.96178 acc=0.30520
# Valid: 034/300, loss=1.84453 acc=0.34271
#
# Epoch 34 has 26 data to do semi-supervise
# Train: 035/300, loss=1.96839 acc=0.29713
# Valid: 035/300, loss=1.87914 acc=0.33776
#
# Epoch 35 has no data doing semi-supervise
# Train: 036/300, loss=1.88684 acc=0.33562
# Valid: 036/300, loss=1.77428 acc=0.38073
#
# Epoch 36 has 56 data to do semi-supervise
# Train: 037/300, loss=1.93766 acc=0.31344
# Valid: 037/300, loss=2.00592 acc=0.30547
#
# Epoch 37 has 11 data to do semi-supervise
# Train: 038/300, loss=1.89370 acc=0.31592
# Valid: 038/300, loss=1.85022 acc=0.33594
#
# Epoch 38 has 35 data to do semi-supervise
# Train: 039/300, loss=1.89812 acc=0.32085
# Valid: 039/300, loss=1.86597 acc=0.34635
#
# Epoch 39 has 85 data to do semi-supervise
# Train: 040/300, loss=1.85036 acc=0.34048
# Valid: 040/300, loss=1.85215 acc=0.35599
#
# Epoch 40 has 1 data to do semi-supervise
# Train: 041/300, loss=1.86225 acc=0.34295
# Valid: 041/300, loss=1.90434 acc=0.36328
#
# Epoch 41 has 252 data to do semi-supervise
# Train: 042/300, loss=1.91007 acc=0.31510
# Valid: 042/300, loss=1.81002 acc=0.33906
#
# Epoch 42 has 40 data to do semi-supervise
# Train: 043/300, loss=1.84738 acc=0.33917
# Valid: 043/300, loss=1.81275 acc=0.36589
#
# Epoch 43 has 45 data to do semi-supervise
# Train: 044/300, loss=1.83197 acc=0.36215
# Valid: 044/300, loss=1.77407 acc=0.36068
#
# Epoch 44 has 3 data to do semi-supervise
# Train: 045/300, loss=1.83536 acc=0.37582
# Valid: 045/300, loss=1.74841 acc=0.38411
#
# Epoch 45 has 157 data to do semi-supervise
# Train: 046/300, loss=1.84268 acc=0.35953
# Valid: 046/300, loss=1.82462 acc=0.33880
#
# Epoch 46 has 18 data to do semi-supervise
# Train: 047/300, loss=1.79879 acc=0.36731
# Valid: 047/300, loss=1.69981 acc=0.40078
#
# Epoch 47 has 63 data to do semi-supervise
# Train: 048/300, loss=1.73757 acc=0.38259
# Valid: 048/300, loss=1.73157 acc=0.42109
#
# Epoch 48 has 37 data to do semi-supervise
# Train: 049/300, loss=1.75525 acc=0.37869
# Valid: 049/300, loss=1.78362 acc=0.37109
#
# Epoch 49 has 23 data to do semi-supervise
# Train: 050/300, loss=1.76575 acc=0.37947
# Valid: 050/300, loss=1.77047 acc=0.39583
#
# Epoch 50 has 155 data to do semi-supervise
# Train: 051/300, loss=1.74776 acc=0.38037
# Valid: 051/300, loss=1.75438 acc=0.39245
#
# Epoch 51 has 9 data to do semi-supervise
# Train: 052/300, loss=1.70849 acc=0.39864
# Valid: 052/300, loss=1.71672 acc=0.43411
#
# Epoch 52 has 245 data to do semi-supervise
# Train: 053/300, loss=1.76928 acc=0.36806
# Valid: 053/300, loss=1.64289 acc=0.44453
#
# Epoch 53 has 21 data to do semi-supervise
# Train: 054/300, loss=1.70355 acc=0.41173
# Valid: 054/300, loss=1.78874 acc=0.38203
#
# Epoch 54 has 168 data to do semi-supervise
# Train: 055/300, loss=1.70865 acc=0.40284
# Valid: 055/300, loss=1.70912 acc=0.40052
#
# Epoch 55 has 7 data to do semi-supervise
# Train: 056/300, loss=1.70654 acc=0.41081
# Valid: 056/300, loss=1.56246 acc=0.45573
#
# Epoch 56 has 42 data to do semi-supervise
# Train: 057/300, loss=1.69558 acc=0.40645
# Valid: 057/300, loss=1.64405 acc=0.46224
#
# Epoch 57 has 101 data to do semi-supervise
# Train: 058/300, loss=1.65986 acc=0.42414
# Valid: 058/300, loss=1.71381 acc=0.40443
#
# Epoch 58 has 52 data to do semi-supervise
# Train: 059/300, loss=1.62837 acc=0.43940
# Valid: 059/300, loss=1.58072 acc=0.45703
#
# Epoch 59 has 91 data to do semi-supervise
# Train: 060/300, loss=1.63689 acc=0.43134
# Valid: 060/300, loss=1.55064 acc=0.43698
#
# Epoch 60 has 24 data to do semi-supervise
# Train: 061/300, loss=1.57637 acc=0.45656
# Valid: 061/300, loss=1.53907 acc=0.45547
#
# Epoch 61 has 102 data to do semi-supervise
# Train: 062/300, loss=1.60778 acc=0.43699
# Valid: 062/300, loss=1.59525 acc=0.48542
#
# Epoch 62 has 65 data to do semi-supervise
# Train: 063/300, loss=1.61404 acc=0.44753
# Valid: 063/300, loss=1.50552 acc=0.48307
#
# Epoch 63 has 39 data to do semi-supervise
# Train: 064/300, loss=1.56180 acc=0.45779
# Valid: 064/300, loss=1.44723 acc=0.51510
#
# Epoch 64 has 172 data to do semi-supervise
# Train: 065/300, loss=1.58211 acc=0.45017
# Valid: 065/300, loss=1.63875 acc=0.44844
#
# Epoch 65 has 55 data to do semi-supervise
# Train: 066/300, loss=1.57947 acc=0.45996
# Valid: 066/300, loss=1.53886 acc=0.48516
#
# Epoch 66 has 171 data to do semi-supervise
# Train: 067/300, loss=1.56354 acc=0.45830
# Valid: 067/300, loss=1.63923 acc=0.47005
#
# Epoch 67 has 36 data to do semi-supervise
# Train: 068/300, loss=1.51341 acc=0.48994
# Valid: 068/300, loss=1.44851 acc=0.49583
#
# Epoch 68 has 255 data to do semi-supervise
# Train: 069/300, loss=1.62567 acc=0.43382
# Valid: 069/300, loss=1.55506 acc=0.47318
#
# Epoch 69 has 68 data to do semi-supervise
# Train: 070/300, loss=1.54455 acc=0.47156
# Valid: 070/300, loss=1.49951 acc=0.48594
#
# Epoch 70 has 351 data to do semi-supervise
# Train: 071/300, loss=1.61002 acc=0.44991
# Valid: 071/300, loss=1.66457 acc=0.39375
#
# Epoch 71 has 11 data to do semi-supervise
# Train: 072/300, loss=1.52281 acc=0.46786
# Valid: 072/300, loss=1.55806 acc=0.48542
#
# Epoch 72 has 258 data to do semi-supervise
# Train: 073/300, loss=1.54082 acc=0.47112
# Valid: 073/300, loss=1.51772 acc=0.48229
#
# Epoch 73 has 22 data to do semi-supervise
# Train: 074/300, loss=1.48444 acc=0.49983
# Valid: 074/300, loss=1.44324 acc=0.52057
#
# Epoch 74 has 182 data to do semi-supervise
# Train: 075/300, loss=1.52783 acc=0.48287
# Valid: 075/300, loss=1.42506 acc=0.51745
#
# Epoch 75 has 131 data to do semi-supervise
# Train: 076/300, loss=1.51412 acc=0.46222
# Valid: 076/300, loss=1.36936 acc=0.57292
#
# Epoch 76 has 154 data to do semi-supervise
# Train: 077/300, loss=1.46973 acc=0.48977
# Valid: 077/300, loss=1.35280 acc=0.53672
#
# Epoch 77 has 70 data to do semi-supervise
# Train: 078/300, loss=1.43143 acc=0.52344
# Valid: 078/300, loss=1.41699 acc=0.55964
#
# Epoch 78 has 439 data to do semi-supervise
# Train: 079/300, loss=1.55287 acc=0.48212
# Valid: 079/300, loss=1.52757 acc=0.50651
#
# Epoch 79 has 70 data to do semi-supervise
# Train: 080/300, loss=1.45185 acc=0.52721
# Valid: 080/300, loss=1.33559 acc=0.54401
#
# Epoch 80 has 385 data to do semi-supervise
# Train: 081/300, loss=1.57360 acc=0.47250
# Valid: 081/300, loss=1.42709 acc=0.51354
#
# Epoch 81 has 49 data to do semi-supervise
# Train: 082/300, loss=1.38362 acc=0.53418
# Valid: 082/300, loss=1.41018 acc=0.52188
#
# Epoch 82 has 424 data to do semi-supervise
# Train: 083/300, loss=1.51394 acc=0.47833
# Valid: 083/300, loss=1.40510 acc=0.55078
#
# Epoch 83 has 89 data to do semi-supervise
# Train: 084/300, loss=1.40037 acc=0.52832
# Valid: 084/300, loss=1.41583 acc=0.51615
#
# Epoch 84 has 471 data to do semi-supervise
# Train: 085/300, loss=1.51103 acc=0.47417
# Valid: 085/300, loss=1.39727 acc=0.53203
#
# Epoch 85 has 107 data to do semi-supervise
# Train: 086/300, loss=1.38935 acc=0.54573
# Valid: 086/300, loss=1.43773 acc=0.52005
#
# Epoch 86 has 600 data to do semi-supervise
# Train: 087/300, loss=1.49712 acc=0.49659
# Valid: 087/300, loss=1.44807 acc=0.49010
#
# Epoch 87 has 24 data to do semi-supervise
# Train: 088/300, loss=1.33654 acc=0.55687
# Valid: 088/300, loss=1.36802 acc=0.55703
#
# Epoch 88 has 369 data to do semi-supervise
# Train: 089/300, loss=1.49305 acc=0.50628
# Valid: 089/300, loss=1.40140 acc=0.52865
#
# Epoch 89 has 172 data to do semi-supervise
# Train: 090/300, loss=1.36935 acc=0.54380
# Valid: 090/300, loss=1.57753 acc=0.57057
#
# Epoch 90 has 493 data to do semi-supervise
# Train: 091/300, loss=1.46337 acc=0.51519
# Valid: 091/300, loss=1.34689 acc=0.53047
#
# Epoch 91 has 109 data to do semi-supervise
# Train: 092/300, loss=1.39979 acc=0.54538
# Valid: 092/300, loss=1.39710 acc=0.54010
#
# Epoch 92 has 363 data to do semi-supervise
# Train: 093/300, loss=1.41265 acc=0.53369
# Valid: 093/300, loss=1.59587 acc=0.50859
#
# Epoch 93 has 387 data to do semi-supervise
# Train: 094/300, loss=1.40837 acc=0.52367
# Valid: 094/300, loss=1.53102 acc=0.50286
#
# Epoch 94 has 588 data to do semi-supervise
# Train: 095/300, loss=1.53422 acc=0.47831
# Valid: 095/300, loss=1.49566 acc=0.49792
#
# Epoch 95 has 109 data to do semi-supervise
# Train: 096/300, loss=1.29455 acc=0.57194
# Valid: 096/300, loss=1.37163 acc=0.57422
#
# Epoch 96 has 593 data to do semi-supervise
# Train: 097/300, loss=1.41566 acc=0.52584
# Valid: 097/300, loss=1.46286 acc=0.53750
#
# Epoch 97 has 98 data to do semi-supervise
# Train: 098/300, loss=1.28538 acc=0.58678
# Valid: 098/300, loss=1.35850 acc=0.59323
#
# Epoch 98 has 459 data to do semi-supervise
# Train: 099/300, loss=1.39030 acc=0.54029
# Valid: 099/300, loss=1.64405 acc=0.50182
#
# Epoch 99 has 382 data to do semi-supervise
# Train: 100/300, loss=1.36119 acc=0.55246
# Valid: 100/300, loss=2.03961 acc=0.55781
#
# Epoch 100 has 862 data to do semi-supervise
# Train: 101/300, loss=1.53136 acc=0.50303
# Valid: 101/300, loss=1.42607 acc=0.54505
#
# Epoch 101 has 157 data to do semi-supervise
# Train: 102/300, loss=1.29297 acc=0.58655
# Valid: 102/300, loss=1.49541 acc=0.53672
#
# Epoch 102 has 790 data to do semi-supervise
# Train: 103/300, loss=1.42118 acc=0.50909
# Valid: 103/300, loss=1.32700 acc=0.54141
#
# Epoch 103 has 142 data to do semi-supervise
# Train: 104/300, loss=1.28953 acc=0.56941
# Valid: 104/300, loss=1.52061 acc=0.55000
#
# Epoch 104 has 736 data to do semi-supervise
# Train: 105/300, loss=1.01826 acc=0.66589
# Valid: 105/300, loss=1.31317 acc=0.58958
#
# Epoch 105 has 1421 data to do semi-supervise
# Train: 106/300, loss=1.58700 acc=0.47497
# Valid: 106/300, loss=1.45477 acc=0.51250
#
# Epoch 106 has 71 data to do semi-supervise
# Train: 107/300, loss=1.32630 acc=0.58289
# Valid: 107/300, loss=1.61718 acc=0.55234
#
# Epoch 107 has 706 data to do semi-supervise
# Train: 108/300, loss=1.27822 acc=0.54288
# Valid: 108/300, loss=1.33020 acc=0.61406
#
# Epoch 108 has 265 data to do semi-supervise
# Train: 109/300, loss=1.37494 acc=0.56704
# Valid: 109/300, loss=1.44942 acc=0.58490
#
# Epoch 109 has 779 data to do semi-supervise
# Train: 110/300, loss=1.36833 acc=0.54993
# Valid: 110/300, loss=1.40337 acc=0.55339
#
# Epoch 110 has 494 data to do semi-supervise
# Train: 111/300, loss=1.25776 acc=0.57906
# Valid: 111/300, loss=1.31943 acc=0.60859
#
# Epoch 111 has 909 data to do semi-supervise
# Train: 112/300, loss=1.11707 acc=0.63695
# Valid: 112/300, loss=1.30482 acc=0.59740
#
# Epoch 112 has 724 data to do semi-supervise
# Train: 113/300, loss=1.36606 acc=0.53687
# Valid: 113/300, loss=1.35260 acc=0.55703
#
# Epoch 113 has 373 data to do semi-supervise
# Train: 114/300, loss=1.23839 acc=0.60009
# Valid: 114/300, loss=1.44140 acc=0.58229
#
# Epoch 114 has 440 data to do semi-supervise
# Train: 115/300, loss=1.03734 acc=0.67020
# Valid: 115/300, loss=1.34798 acc=0.59818
#
# Epoch 115 has 1312 data to do semi-supervise
# Train: 116/300, loss=1.45360 acc=0.49701
# Valid: 116/300, loss=1.50020 acc=0.52500
#
# Epoch 116 has 44 data to do semi-supervise
# Train: 117/300, loss=1.16905 acc=0.60906
# Valid: 117/300, loss=1.33877 acc=0.60651
#
# Epoch 117 has 1070 data to do semi-supervise
# Train: 118/300, loss=1.32215 acc=0.51520
# Valid: 118/300, loss=1.41237 acc=0.56615
#
# Epoch 118 has 200 data to do semi-supervise
# Train: 119/300, loss=1.17043 acc=0.62488
# Valid: 119/300, loss=1.32334 acc=0.57552
#
# Epoch 119 has 755 data to do semi-supervise
# Train: 120/300, loss=1.09914 acc=0.62330
# Valid: 120/300, loss=1.25634 acc=0.60547
#
# Epoch 120 has 957 data to do semi-supervise
# Train: 121/300, loss=0.89646 acc=0.71168
# Valid: 121/300, loss=1.24517 acc=0.59453
#
# Epoch 121 has 1801 data to do semi-supervise
# Train: 122/300, loss=0.87650 acc=0.72144
# Valid: 122/300, loss=1.44350 acc=0.56354
#
# Epoch 122 has 2100 data to do semi-supervise
# Train: 123/300, loss=0.85123 acc=0.71932
# Valid: 123/300, loss=1.17704 acc=0.62891
#
# Epoch 123 has 2107 data to do semi-supervise
# Train: 124/300, loss=0.83525 acc=0.72318
# Valid: 124/300, loss=1.20377 acc=0.62318
#
# Epoch 124 has 1942 data to do semi-supervise
# Train: 125/300, loss=1.17938 acc=0.61949
# Valid: 125/300, loss=1.52416 acc=0.52474
#
# Epoch 125 has 1029 data to do semi-supervise
# Train: 126/300, loss=1.00128 acc=0.68054
# Valid: 126/300, loss=1.47203 acc=0.60365
#
# Epoch 126 has 1238 data to do semi-supervise
# Train: 127/300, loss=0.92046 acc=0.71051
# Valid: 127/300, loss=1.37704 acc=0.57839
#
# Epoch 127 has 1747 data to do semi-supervise
# Train: 128/300, loss=0.82602 acc=0.73879
# Valid: 128/300, loss=1.16897 acc=0.63438
#
# Epoch 128 has 1983 data to do semi-supervise
# Train: 129/300, loss=0.74808 acc=0.75132
# Valid: 129/300, loss=1.29783 acc=0.60781
#
# Epoch 129 has 2171 data to do semi-supervise
# Train: 130/300, loss=0.79371 acc=0.73878
# Valid: 130/300, loss=1.24067 acc=0.59193
#
# Epoch 130 has 2096 data to do semi-supervise
# Train: 131/300, loss=0.74937 acc=0.74861
# Valid: 131/300, loss=1.35409 acc=0.56823
#
# Epoch 131 has 2292 data to do semi-supervise
# Train: 132/300, loss=1.12424 acc=0.62571
# Valid: 132/300, loss=1.54216 acc=0.52630
#
# Epoch 132 has 1031 data to do semi-supervise
# Train: 133/300, loss=0.88384 acc=0.72075
# Valid: 133/300, loss=1.30510 acc=0.60911
#
# Epoch 133 has 1741 data to do semi-supervise
# Train: 134/300, loss=0.77635 acc=0.75635
# Valid: 134/300, loss=1.33026 acc=0.61797
#
# Epoch 134 has 2399 data to do semi-supervise
# Train: 135/300, loss=0.78723 acc=0.74995
# Valid: 135/300, loss=1.41653 acc=0.57188
#
# Epoch 135 has 2174 data to do semi-supervise
# Train: 136/300, loss=0.74052 acc=0.76531
# Valid: 136/300, loss=1.38265 acc=0.60703
#
# Epoch 136 has 2296 data to do semi-supervise
# Train: 137/300, loss=0.75315 acc=0.75577
# Valid: 137/300, loss=1.25652 acc=0.61667
#
# Epoch 137 has 2091 data to do semi-supervise
# Train: 138/300, loss=0.71812 acc=0.76913
# Valid: 138/300, loss=1.17729 acc=0.63854
#
# Epoch 138 has 2260 data to do semi-supervise
# Train: 139/300, loss=0.70987 acc=0.76042
# Valid: 139/300, loss=1.15597 acc=0.65365
#
# Epoch 139 has 2305 data to do semi-supervise
# Train: 140/300, loss=0.68814 acc=0.77223
# Valid: 140/300, loss=1.24509 acc=0.61771
#
# Epoch 140 has 2820 data to do semi-supervise
# Train: 141/300, loss=0.68256 acc=0.78020
# Valid: 141/300, loss=1.16306 acc=0.62786
#
# Epoch 141 has 2673 data to do semi-supervise
# Train: 142/300, loss=0.68417 acc=0.76990
# Valid: 142/300, loss=1.16094 acc=0.64349
#
# Epoch 142 has 2443 data to do semi-supervise
# Train: 143/300, loss=0.70276 acc=0.76529
# Valid: 143/300, loss=1.15014 acc=0.65573
#
# Epoch 143 has 2449 data to do semi-supervise
# Train: 144/300, loss=0.68132 acc=0.77611
# Valid: 144/300, loss=1.23332 acc=0.63802
#
# Epoch 144 has 2347 data to do semi-supervise
# Train: 145/300, loss=0.66446 acc=0.78623
# Valid: 145/300, loss=1.15906 acc=0.63620
#
# Epoch 145 has 2427 data to do semi-supervise
# Train: 146/300, loss=0.64376 acc=0.79551
# Valid: 146/300, loss=1.16991 acc=0.64922
#
# Epoch 146 has 2703 data to do semi-supervise
# Train: 147/300, loss=0.66122 acc=0.79072
# Valid: 147/300, loss=1.56217 acc=0.62943
#
# Epoch 147 has 2735 data to do semi-supervise
# Train: 148/300, loss=0.66355 acc=0.78500
# Valid: 148/300, loss=2.36892 acc=0.59349
#
# Epoch 148 has 2681 data to do semi-supervise
# Train: 149/300, loss=0.81924 acc=0.77089
# Valid: 149/300, loss=1.31805 acc=0.64141
#
# Epoch 149 has 2676 data to do semi-supervise
# Train: 150/300, loss=0.65866 acc=0.78959
# Valid: 150/300, loss=1.29558 acc=0.64896
#
# Epoch 150 has 2788 data to do semi-supervise
# Train: 151/300, loss=1.01037 acc=0.67987
# Valid: 151/300, loss=1.45523 acc=0.53828
#
# Epoch 151 has 1454 data to do semi-supervise
# Train: 152/300, loss=0.78106 acc=0.75440
# Valid: 152/300, loss=1.51475 acc=0.60651
#
# Epoch 152 has 2433 data to do semi-supervise
# Train: 153/300, loss=0.72176 acc=0.77150
# Valid: 153/300, loss=1.48180 acc=0.63229
#
# Epoch 153 has 2463 data to do semi-supervise
# Train: 154/300, loss=0.64825 acc=0.79138
# Valid: 154/300, loss=1.26411 acc=0.63385
#
# Epoch 154 has 2698 data to do semi-supervise
# Train: 155/300, loss=0.64044 acc=0.79576
# Valid: 155/300, loss=1.48717 acc=0.65833
#
# Epoch 155 has 2950 data to do semi-supervise
# Train: 156/300, loss=0.69123 acc=0.77797
# Valid: 156/300, loss=1.77001 acc=0.63359
#
# Epoch 156 has 2671 data to do semi-supervise
# Train: 157/300, loss=0.64503 acc=0.78617
# Valid: 157/300, loss=1.18598 acc=0.66563
#
# Epoch 157 has 2892 data to do semi-supervise
# Train: 158/300, loss=0.63768 acc=0.78939
# Valid: 158/300, loss=1.34854 acc=0.64896
#
# Epoch 158 has 2812 data to do semi-supervise
# Train: 159/300, loss=0.65756 acc=0.78507
# Valid: 159/300, loss=1.34308 acc=0.60286
#
# Epoch 159 has 2832 data to do semi-supervise
# Train: 160/300, loss=0.65908 acc=0.78779
# Valid: 160/300, loss=1.32043 acc=0.62708
#
# Epoch 160 has 2851 data to do semi-supervise
# Train: 161/300, loss=0.63199 acc=0.79011
# Valid: 161/300, loss=1.29010 acc=0.60052
#
# Epoch 161 has 2845 data to do semi-supervise
# Train: 162/300, loss=0.60267 acc=0.80525
# Valid: 162/300, loss=1.25772 acc=0.61745
#
# Epoch 162 has 2945 data to do semi-supervise
# Train: 163/300, loss=0.64778 acc=0.79422
# Valid: 163/300, loss=1.06428 acc=0.67500
#
# Epoch 163 has 2939 data to do semi-supervise
# Train: 164/300, loss=0.58315 acc=0.80783
# Valid: 164/300, loss=1.17368 acc=0.62682
#
# Epoch 164 has 3161 data to do semi-supervise
# Train: 165/300, loss=0.58487 acc=0.80797
# Valid: 165/300, loss=1.20926 acc=0.64505
#
# Epoch 165 has 3071 data to do semi-supervise
# Train: 166/300, loss=0.59854 acc=0.80425
# Valid: 166/300, loss=1.20340 acc=0.66016
#
# Epoch 166 has 2994 data to do semi-supervise
# Train: 167/300, loss=0.62105 acc=0.79878
# Valid: 167/300, loss=1.24517 acc=0.62813
#
# Epoch 167 has 3045 data to do semi-supervise
# Train: 168/300, loss=0.58633 acc=0.80902
# Valid: 168/300, loss=1.41762 acc=0.60573
#
# Epoch 168 has 3161 data to do semi-supervise
# Train: 169/300, loss=0.58712 acc=0.80829
# Valid: 169/300, loss=1.16182 acc=0.64792
#
# Epoch 169 has 3068 data to do semi-supervise
# Train: 170/300, loss=0.61215 acc=0.80947
# Valid: 170/300, loss=1.07666 acc=0.68620
#
# Epoch 170 has 3297 data to do semi-supervise
# Train: 171/300, loss=0.57552 acc=0.81006
# Valid: 171/300, loss=1.15265 acc=0.66693
#
# Epoch 171 has 3075 data to do semi-supervise
# Train: 172/300, loss=0.53682 acc=0.82118
# Valid: 172/300, loss=1.09467 acc=0.66563
#
# Epoch 172 has 3396 data to do semi-supervise
# Train: 173/300, loss=0.56275 acc=0.81797
# Valid: 173/300, loss=1.15512 acc=0.67266
#
# Epoch 173 has 3444 data to do semi-supervise
# Train: 174/300, loss=0.53273 acc=0.82677
# Valid: 174/300, loss=1.11155 acc=0.66797
#
# Epoch 174 has 3221 data to do semi-supervise
# Train: 175/300, loss=0.51146 acc=0.82830
# Valid: 175/300, loss=1.33909 acc=0.62161
#
# Epoch 175 has 3526 data to do semi-supervise
# Train: 176/300, loss=0.56184 acc=0.81532
# Valid: 176/300, loss=1.16451 acc=0.66615
#
# Epoch 176 has 3154 data to do semi-supervise
# Train: 177/300, loss=0.52261 acc=0.82174
# Valid: 177/300, loss=1.12845 acc=0.67005
#
# Epoch 177 has 3512 data to do semi-supervise
# Train: 178/300, loss=0.53354 acc=0.82151
# Valid: 178/300, loss=1.21103 acc=0.66693
#
# Epoch 178 has 3201 data to do semi-supervise
# Train: 179/300, loss=0.55212 acc=0.82665
# Valid: 179/300, loss=1.21957 acc=0.64766
#
# Epoch 179 has 3173 data to do semi-supervise
# Train: 180/300, loss=0.53118 acc=0.81944
# Valid: 180/300, loss=1.29151 acc=0.65260
#
# Epoch 180 has 3505 data to do semi-supervise
# Train: 181/300, loss=0.54562 acc=0.81893
# Valid: 181/300, loss=1.17703 acc=0.68828
#
# Epoch 181 has 3268 data to do semi-supervise
# Train: 182/300, loss=0.51457 acc=0.83173
# Valid: 182/300, loss=1.26136 acc=0.63594
#
# Epoch 182 has 3280 data to do semi-supervise
# Train: 183/300, loss=0.49271 acc=0.83977
# Valid: 183/300, loss=1.00815 acc=0.69714
#
# Epoch 183 has 3449 data to do semi-supervise
# Train: 184/300, loss=0.55077 acc=0.81325
# Valid: 184/300, loss=1.27988 acc=0.63802
#
# Epoch 184 has 3381 data to do semi-supervise
# Train: 185/300, loss=0.52731 acc=0.82006
# Valid: 185/300, loss=1.19174 acc=0.67917
#
# Epoch 185 has 3468 data to do semi-supervise
# Train: 186/300, loss=0.52950 acc=0.82891
# Valid: 186/300, loss=1.22081 acc=0.65234
#
# Epoch 186 has 3552 data to do semi-supervise
# Train: 187/300, loss=0.54924 acc=0.81324
# Valid: 187/300, loss=1.10517 acc=0.68177
#
# Epoch 187 has 3389 data to do semi-supervise
# Train: 188/300, loss=0.50567 acc=0.82789
# Valid: 188/300, loss=1.14793 acc=0.66563
#
# Epoch 188 has 3626 data to do semi-supervise
# Train: 189/300, loss=0.49759 acc=0.83292
# Valid: 189/300, loss=1.11285 acc=0.68828
#
# Epoch 189 has 3629 data to do semi-supervise
# Train: 190/300, loss=0.51404 acc=0.83152
# Valid: 190/300, loss=1.09789 acc=0.69193
#
# Epoch 190 has 3419 data to do semi-supervise
# Train: 191/300, loss=0.49357 acc=0.83796
# Valid: 191/300, loss=1.18976 acc=0.67370
#
# Epoch 191 has 3519 data to do semi-supervise
# Train: 192/300, loss=0.50773 acc=0.83795
# Valid: 192/300, loss=1.11031 acc=0.69844
#
# Epoch 192 has 3500 data to do semi-supervise
# Train: 193/300, loss=0.47014 acc=0.84717
# Valid: 193/300, loss=1.19983 acc=0.67240
#
# Epoch 193 has 3550 data to do semi-supervise
# Train: 194/300, loss=0.50001 acc=0.83709
# Valid: 194/300, loss=1.23337 acc=0.65625
#
# Epoch 194 has 3588 data to do semi-supervise
# Train: 195/300, loss=0.51739 acc=0.82808
# Valid: 195/300, loss=1.10843 acc=0.68047
#
# Epoch 195 has 3534 data to do semi-supervise
# Train: 196/300, loss=0.50888 acc=0.83273
# Valid: 196/300, loss=1.22794 acc=0.66042
#
# Epoch 196 has 3712 data to do semi-supervise
# Train: 197/300, loss=0.51906 acc=0.82812
# Valid: 197/300, loss=1.16338 acc=0.69036
#
# Epoch 197 has 3628 data to do semi-supervise
# Train: 198/300, loss=0.48413 acc=0.84166
# Valid: 198/300, loss=1.19557 acc=0.64479
#
# Epoch 198 has 3777 data to do semi-supervise
# Train: 199/300, loss=0.50537 acc=0.83622
# Valid: 199/300, loss=1.03792 acc=0.69010
#
# Epoch 199 has 3515 data to do semi-supervise
# Train: 200/300, loss=0.47858 acc=0.84382
# Valid: 200/300, loss=1.23501 acc=0.65859
#
# Epoch 200 has 3699 data to do semi-supervise
# Train: 201/300, loss=0.47648 acc=0.84141
# Valid: 201/300, loss=1.29656 acc=0.66875
#
# Epoch 201 has 3650 data to do semi-supervise
# Train: 202/300, loss=0.49933 acc=0.84092
# Valid: 202/300, loss=1.22338 acc=0.67474
#
# Epoch 202 has 3731 data to do semi-supervise
# Train: 203/300, loss=0.47357 acc=0.84238
# Valid: 203/300, loss=1.16768 acc=0.66250
#
# Epoch 203 has 3705 data to do semi-supervise
# Train: 204/300, loss=0.49809 acc=0.83464
# Valid: 204/300, loss=1.26549 acc=0.66250
#
# Epoch 204 has 3778 data to do semi-supervise
# Train: 205/300, loss=0.48340 acc=0.84244
# Valid: 205/300, loss=1.09616 acc=0.69948
#
# Epoch 205 has 3925 data to do semi-supervise
# Train: 206/300, loss=0.46469 acc=0.84524
# Valid: 206/300, loss=1.10400 acc=0.67396
#
# Epoch 206 has 3677 data to do semi-supervise
# Train: 207/300, loss=0.44654 acc=0.84820
# Valid: 207/300, loss=1.21660 acc=0.68958
#
# Epoch 207 has 3790 data to do semi-supervise
# Train: 208/300, loss=0.48724 acc=0.83516
# Valid: 208/300, loss=1.16370 acc=0.68490
#
# Epoch 208 has 3779 data to do semi-supervise
# Train: 209/300, loss=0.46847 acc=0.84542
# Valid: 209/300, loss=1.30025 acc=0.64818
#
# Epoch 209 has 3966 data to do semi-supervise
# Train: 210/300, loss=0.46271 acc=0.84947
# Valid: 210/300, loss=1.43075 acc=0.62344
#
# Epoch 210 has 3879 data to do semi-supervise
# Train: 211/300, loss=0.46724 acc=0.84901
# Valid: 211/300, loss=1.31336 acc=0.66693
#
# Epoch 211 has 3879 data to do semi-supervise
# Train: 212/300, loss=0.46997 acc=0.84425
# Valid: 212/300, loss=1.09475 acc=0.69661
#
# Epoch 212 has 3792 data to do semi-supervise
# Train: 213/300, loss=0.43231 acc=0.85477
# Valid: 213/300, loss=1.26391 acc=0.66641
#
# Epoch 213 has 4046 data to do semi-supervise
# Train: 214/300, loss=0.46584 acc=0.85312
# Valid: 214/300, loss=1.17628 acc=0.66224
#
# Epoch 214 has 3971 data to do semi-supervise
# Train: 215/300, loss=0.47836 acc=0.84631
# Valid: 215/300, loss=1.00889 acc=0.70625
#
# Epoch 215 has 3718 data to do semi-supervise
# Train: 216/300, loss=0.44557 acc=0.85499
# Valid: 216/300, loss=1.10342 acc=0.71797
#
# Epoch 216 has 4007 data to do semi-supervise
# Train: 217/300, loss=0.44996 acc=0.85195
# Valid: 217/300, loss=1.16618 acc=0.68750
#
# Epoch 217 has 3921 data to do semi-supervise
# Train: 218/300, loss=0.45618 acc=0.84026
# Valid: 218/300, loss=1.13685 acc=0.69922
#
# Epoch 218 has 3663 data to do semi-supervise
# Train: 219/300, loss=0.44959 acc=0.85000
# Valid: 219/300, loss=1.20268 acc=0.67109
#
# Epoch 219 has 3849 data to do semi-supervise
# Train: 220/300, loss=0.46072 acc=0.85041
# Valid: 220/300, loss=1.03961 acc=0.70443
#
# Epoch 220 has 3681 data to do semi-supervise
# Train: 221/300, loss=0.42768 acc=0.85888
# Valid: 221/300, loss=1.09831 acc=0.69089
#
# Epoch 221 has 4017 data to do semi-supervise
# Train: 222/300, loss=0.47051 acc=0.84198
# Valid: 222/300, loss=1.25009 acc=0.66328
#
# Epoch 222 has 3988 data to do semi-supervise
# Train: 223/300, loss=0.47358 acc=0.84608
# Valid: 223/300, loss=1.20197 acc=0.65599
#
# Epoch 223 has 3951 data to do semi-supervise
# Train: 224/300, loss=0.42190 acc=0.86003
# Valid: 224/300, loss=1.18717 acc=0.67630
#
# Epoch 224 has 4044 data to do semi-supervise
# Train: 225/300, loss=0.45135 acc=0.85109
# Valid: 225/300, loss=1.33505 acc=0.64193
#
# Epoch 225 has 3825 data to do semi-supervise
# Train: 226/300, loss=0.44189 acc=0.85560
# Valid: 226/300, loss=1.24396 acc=0.68437
#
# Epoch 226 has 4041 data to do semi-supervise
# Train: 227/300, loss=0.45178 acc=0.85560
# Valid: 227/300, loss=1.09630 acc=0.70182
#
# Epoch 227 has 3847 data to do semi-supervise
# Train: 228/300, loss=0.43324 acc=0.85672
# Valid: 228/300, loss=1.11370 acc=0.68958
#
# Epoch 228 has 4029 data to do semi-supervise
# Train: 229/300, loss=0.48610 acc=0.83815
# Valid: 229/300, loss=1.21405 acc=0.65703
#
# Epoch 229 has 3929 data to do semi-supervise
# Train: 230/300, loss=0.43276 acc=0.86077
# Valid: 230/300, loss=0.98043 acc=0.73802
#
# Epoch 230 has 3997 data to do semi-supervise
# Train: 231/300, loss=0.44324 acc=0.85517
# Valid: 231/300, loss=0.97740 acc=0.73359
#
# Epoch 231 has 3987 data to do semi-supervise
# Train: 232/300, loss=0.45051 acc=0.85174
# Valid: 232/300, loss=1.13068 acc=0.70938
#
# Epoch 232 has 4002 data to do semi-supervise
# Train: 233/300, loss=0.42860 acc=0.85471
# Valid: 233/300, loss=1.16899 acc=0.70365
#
# Epoch 233 has 4103 data to do semi-supervise
# Train: 234/300, loss=0.41234 acc=0.86346
# Valid: 234/300, loss=1.34084 acc=0.65234
#
# Epoch 234 has 4331 data to do semi-supervise
# Train: 235/300, loss=0.44195 acc=0.84966
# Valid: 235/300, loss=1.16237 acc=0.67891
#
# Epoch 235 has 4212 data to do semi-supervise
# Train: 236/300, loss=0.39293 acc=0.86957
# Valid: 236/300, loss=1.29930 acc=0.67917
#
# Epoch 236 has 4215 data to do semi-supervise
# Train: 237/300, loss=0.41805 acc=0.86292
# Valid: 237/300, loss=1.09181 acc=0.70911
#
# Epoch 237 has 4119 data to do semi-supervise
# Train: 238/300, loss=0.40890 acc=0.86412
# Valid: 238/300, loss=1.13218 acc=0.72526
#
# Epoch 238 has 4283 data to do semi-supervise
# Train: 239/300, loss=0.41552 acc=0.86214
# Valid: 239/300, loss=1.08350 acc=0.70573
#
# Epoch 239 has 4330 data to do semi-supervise
# Train: 240/300, loss=0.45362 acc=0.85111
# Valid: 240/300, loss=1.23840 acc=0.68281
#
# Epoch 240 has 4066 data to do semi-supervise
# Train: 241/300, loss=0.40882 acc=0.86725
# Valid: 241/300, loss=1.11619 acc=0.69714
#
# Epoch 241 has 4058 data to do semi-supervise
# Train: 242/300, loss=0.43088 acc=0.85790
# Valid: 242/300, loss=1.06264 acc=0.73490
#
# Epoch 242 has 4212 data to do semi-supervise
# Train: 243/300, loss=0.41910 acc=0.86612
# Valid: 243/300, loss=1.21822 acc=0.70286
#
# Epoch 243 has 4145 data to do semi-supervise
# Train: 244/300, loss=0.41648 acc=0.86154
# Valid: 244/300, loss=1.51802 acc=0.67604
#
# Epoch 244 has 4136 data to do semi-supervise
# Train: 245/300, loss=0.43827 acc=0.85837
# Valid: 245/300, loss=1.56637 acc=0.66563
#
# Epoch 245 has 4155 data to do semi-supervise
# Train: 246/300, loss=0.45741 acc=0.85169
# Valid: 246/300, loss=1.18445 acc=0.69479
#
# Epoch 246 has 4057 data to do semi-supervise
# Train: 247/300, loss=0.41185 acc=0.86843
# Valid: 247/300, loss=1.14237 acc=0.71693
#
# Epoch 247 has 4062 data to do semi-supervise
# Train: 248/300, loss=0.39678 acc=0.87293
# Valid: 248/300, loss=1.18799 acc=0.69818
#
# Epoch 248 has 4404 data to do semi-supervise
# Train: 249/300, loss=0.42328 acc=0.85778
# Valid: 249/300, loss=1.21611 acc=0.70521
#
# Epoch 249 has 4143 data to do semi-supervise
# Train: 250/300, loss=0.42419 acc=0.86331
# Valid: 250/300, loss=1.24690 acc=0.70000
#
# Epoch 250 has 4331 data to do semi-supervise
# Train: 251/300, loss=0.43871 acc=0.85629
# Valid: 251/300, loss=1.25393 acc=0.69792
#
# Epoch 251 has 4111 data to do semi-supervise
# Train: 252/300, loss=0.41407 acc=0.86606
# Valid: 252/300, loss=1.52490 acc=0.66042
#
# Epoch 252 has 4200 data to do semi-supervise
# Train: 253/300, loss=0.40576 acc=0.86652
# Valid: 253/300, loss=1.29962 acc=0.68255
#
# Epoch 253 has 4329 data to do semi-supervise
# Train: 254/300, loss=0.40717 acc=0.86459
# Valid: 254/300, loss=1.19848 acc=0.69974
#
# Epoch 254 has 4275 data to do semi-supervise
# Train: 255/300, loss=0.41083 acc=0.86433
# Valid: 255/300, loss=1.35436 acc=0.64531
#
# Epoch 255 has 4380 data to do semi-supervise
# Train: 256/300, loss=0.43635 acc=0.85515
# Valid: 256/300, loss=1.27678 acc=0.68854
#
# Epoch 256 has 4297 data to do semi-supervise
# Train: 257/300, loss=0.40024 acc=0.86867
# Valid: 257/300, loss=1.24029 acc=0.68854
#
# Epoch 257 has 4322 data to do semi-supervise
# Train: 258/300, loss=0.39397 acc=0.87038
# Valid: 258/300, loss=1.04902 acc=0.72344
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 258 has 4408 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 259 has 4390 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 260 has 4325 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 261 has 4401 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 262 has 4323 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 263 has 4379 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 264 has 4326 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 265 has 4345 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 266 has 4124 data to do semi-supervise
#   0%|          | 0/57 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 267 has 4246 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 268 has 4305 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 269 has 4503 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 270 has 4294 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 271 has 4300 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 272 has 4258 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 273 has 4513 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 274 has 4492 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 275 has 4441 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 276 has 4349 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 277 has 4617 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 278 has 4301 data to do semi-supervise
#   0%|          | 0/58 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 279 has 4536 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 280 has 4485 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 281 has 4570 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 282 has 4492 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 283 has 4529 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 284 has 4536 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 285 has 4600 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 286 has 4530 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 287 has 4476 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 288 has 4617 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 289 has 4480 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 290 has 4426 data to do semi-supervise
#   0%|          | 0/59 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 291 has 4644 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 292 has 4629 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 293 has 4621 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 294 has 4626 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 295 has 4695 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 296 has 4733 data to do semi-supervise
#   0%|          | 0/62 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 297 has 4544 data to do semi-supervise
#   0%|          | 0/60 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 298 has 4658 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/54 [00:00<?, ?it/s]
# Epoch 299 has 4636 data to do semi-supervise
#   0%|          | 0/61 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]

# %% [markdown]
# 3:30:00 100epochs
#
# 5:01:22 200
#
# 2:55:15 258
#
# 2:00:00 300

# %%
import matplotlib.pyplot as plt
def plot_graphs(history, string):
  plt.plot(history.metrics['train_'+string])
  plt.plot(history.metrics['valid_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend(['train_'+string, 'valid_'+string])
  plt.show()

plot_graphs(history, "loss")
plot_graphs(history, "acc")

# %%
def plot_semi_count(history):
  plt.plot(history.metrics['semi_count'])
  plt.xlabel("Epochs")
  plt.ylabel("semi_count")
  plt.ylim(-6786*0.05,6786*1.1)
  plt.show()
  
plot_semi_count(history)

# %%
load_epoch = 300
cp = torch.load(store_path+f"model_{load_epoch-1}.pt")
model.load_state_dict(cp['model_state_dict'])
optimizer.load_state_dict(cp['optimizer_state_dict'])

# %% [markdown]
# ## **測試**
#
# 對於資料推測，我們需要確保模型處於 eval 模式，並且數據集的順序不應打亂（test_loader 中的“shuffle=False”）。
#
#
# 最後但並非最不重要的一點是，不要忘記將預測保存到單個 CSV 文件中。
# CSV 文件的格式請參照範例 CSV 的內容
#
# ### **注意 -- 請牢記以下規則**
#
# ## 以下屬於作弊行為:
# - 使用測試的 labels
# - 找打手
# - 每組一天只能上傳五次，請勿用任何方式上傳超過五次
# - 伺服器又貴又脆弱，請不要攻擊它QQ
# - 請不要把你的預測資料給其他同學上傳
# - 請不要分享你的 CODE 給其他同學或是其他生物
# - 請勿使用你用其他管道拿到其它的食物資料，或是在網路上找到的其他的食物資料
# - 伺服器會記錄你每次上傳的答案，所以很容易抓到你上傳其他同學的資料
# - 違反以上任何規則，以作弊論，期末作業直接0分，不得異議
#
# 任何違規行為都會給直接讓你期末成績不及格
#
# 檢查你的程式碼是否違反規則是你自己的的責任。
#
# 在引用來自網路上的程式碼時，您應該知道這些程式碼究竟是做什麼的。
# 如果您違反規則並聲稱你不知道這些程式碼的作用，你將**不**被容忍。

# %%
# Make sure the model is in eval mode.
# Some modules like Dropout or BatchNorm affect if the model is in training mode.
model.eval()

# Initialize a list to store the predictions.
predictions = []

# Iterate the testing set by batches.
for batch in tqdm(test_loader):
    # A batch consists of image data and corresponding labels.
    # But here the variable "labels" is useless since we do not have the ground-truth.
    # If printing out the labels, you will find that it is always 0.
    # This is because the wrapper (DatasetFolder) returns images and labels for each batch,
    # so we have to create fake labels to make it work normally.
    imgs, labels = batch

    # We don't need gradient in testing, and we don't even have labels to compute loss.
    # Using torch.no_grad() accelerates the forward process.
    with torch.no_grad():
        logits = model(imgs.to(device))

    # Take the class with greatest logit as prediction and record it.
    predictions.extend(logits.argmax(dim=-1).cpu().numpy().tolist())
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]

# %%
# Save predictions into the file.
with open("predict.csv", "w") as f:

    # The first row must be "Id, Category"
    f.write("Id,Category\n")

    # For the rest of the rows, each image id corresponds to a predicted class.
    for i, pred in  enumerate(predictions):
         f.write(f"{i},{pred}\n")
